# %%
from google.colab import files
files.upload()

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
image=cv2.imread('/content/Chess Board Blank Image _ Daily Cliparts - Google Chrome 17-11-2020 14_41_15 (2).png')
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
gray=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)

gray=np.float32(gray)
#detect corner
dst=cv2.cornerHarris(gray,2,3,0.04)
plt.imshow(dst,cmap='gray')

# %% [markdown]
# ###dilate corner image to enhance visibility

# %%
dilate=cv2.dilate(dst,None)
plt.imshow(dilate,cmap='gray')

# %% [markdown]
# ####SELECTING and displaying strong corners

# %%
thresh=0.01*dst.max()
corner_image=np.copy(image)
for j in range(0,dst.shape[0]):
  for i in range(0,dst.shape[1]):
    if dst[j,i]>thresh:
      cv2.circle(corner_image,(i,j),3,(0,255,0),1)
plt.imshow(corner_image)
