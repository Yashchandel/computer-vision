# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4bf7c045-f47a-46c3-aa37-7a69904c78d7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4bf7c045-f47a-46c3-aa37-7a69904c78d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat.jpg to cat.jpg
# ...

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %notebook
# Out:
# UsageError: the following arguments are required: filename

# %%
image=cv2.imread('/content/WhatsApp Image 2020-11-07 at 4.36.59 PM.jpeg')

# %%
# gray_img=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
plt.imshow(image)

# %%
image.shape
# Out:
# (435, 693, 3)

# %%
image_copy=np.copy(image)
image_copy=cv2.cvtColor(image_copy,cv2.COLOR_BGR2RGB)
plt.imshow(image_copy)

# %% [markdown]
# ##Create Mask

# %%
lower_blue=np.array([0,0,220])
higher_blue=np.array([50,70,255])
mask=cv2.inRange(image_copy,lower_blue,higher_blue)
plt.imshow(mask,cmap='gray')

# %%
masked_image=np.copy(image_copy)
masked_image[mask!=0]=[0,0,0]
plt.imshow(masked_image,cmap='gray')

# %%
back=cv2.imread('/content/cat.jpg')
back=cv2.cvtColor(back,cv2.COLOR_BGR2RGB)
plt.imshow(back)

# %%
back_image=back[:435,150:150+693]
plt.imshow(back_image)

# %%
back_image[mask==0] = [0,0,0]
plt.imshow(back_image)

# %%
Final_image=back_image+masked_image

# %%
plt.imshow(Final_image)
