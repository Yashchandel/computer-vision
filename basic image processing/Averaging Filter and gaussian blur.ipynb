# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
from google.colab import files
files.upload()

# %%
image=cv2.imread('/content/Normal_axial_T2-weighted_MR_image_of_the_brain.jpg')
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %% [markdown]
# ###AVeraging Filter

# %%
image_copy=np.copy(image)
gray_image=cv2.cvtColor(image_copy,cv2.COLOR_RGB2GRAY)
plt.imshow(gray_image,cmap='gray')

# %%
gray_image.shape
# Out:
# (449, 359)

# %%
kernel=np.array([[1,1,1],[1,1,1],[1,1,1]])/9
filter_image=cv2.filter2D(gray_image,-1,kernel)
plt.imshow(filter_image,cmap='gray')

# %% [markdown]
# ###Guassian Blur

# %%
guas_blur=cv2.GaussianBlur(gray_image,(5,5),0)
plt.imshow(guas_blur,cmap='gray')

# %% [markdown]
# Testing high pass filter on various images

# %%
sobel_x=np.array([[-2,0,2],[-1,0,1],[-2,0,2]])
F=cv2.filter2D(gray_image,-1,sobel_x)
F1=cv2.filter2D(filter_image,-1,sobel_x)#Averaging filter
F2=cv2.filter2D(guas_blur,-1,sobel_x)#Guassian blur
f,(ax1,ax2,ax3)=plt.subplots(3,figsize=(20,20))
ax1.set_title('original_gray')
ax1.imshow(F,cmap='gray')
ax2.set_title('Averaging Filter')
ax2.imshow(F1,cmap='gray')
ax3.set_title('Guassian Blur')
ax3.imshow(F2,cmap='gray')
